# %% [markdown]
# <a href="https://colab.research.google.com/github/kamranshahid56-tech/Credit_Card_Fraud_Detection_Using_ML/blob/main/Credit_Card_Fraud_Detection_Using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249556 entries, 0 to 249555
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    249556 non-null  float64
#  1   V1      249556 non-null  float64
#  2   V2      249556 non-null  float64
#  3   V3      249556 non-null  float64
#  4   V4      249556 non-null  float64
#  5   V5      249556 non-null  float64
#  6   V6      249556 non-null  float64
#  7   V7      249556 non-null  float64
#  8   V8      249556 non-null  float64
#  9   V9      249556 non-null  float64
#  10  V10     249556 non-null  float64
#  11  V11     249556 non-null  float64
#  12  V12     249556 non-null  float64
#  13  V13     249556 non-null  float64
#  14  V14     249556 non-null  float64
#  15  V15     249556 non-null  float64
#  16  V16     249556 non-null  float64
#  17  V17     249556 non-null  float64
#  18  V18     249556 non-null  float64
#  19  V19     249556 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    249100
# 1.0       455
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unbalanced
#
# 0 ---> Normal Transaction
#
# 1 ---> Fraudulent Transaction

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
legit.shape
# Out:
# (249100, 31)

# %%
fraud.shape
# Out:
# (455, 31)

# %%
legit.Amount.describe()
# Out:
# count    249100.000000
# mean         90.671894
# std         251.697188
# min           0.000000
# 25%           6.000000
# 50%          23.060000
# 75%          79.900000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     455.000000
# mean      125.899253
# std       263.669720
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.940000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0.0    85221.772365 -0.028625 -0.027160  ... -0.000903  0.000697   90.671894
# 1.0    74238.189011 -5.061266  3.797424  ...  0.154087  0.075490  125.899253
#
# [2 rows x 30 columns]

# %% [markdown]
# **Under Sampling**
#
# Build a dataset containing similar distributions of normal and fraudulent transactions

# %%
legit_dataset = legit.sample(n=455)

# %%
new_dataset = pd.concat([legit_dataset, fraud], axis = 0)

# %%
new_dataset.shape
# Out:
# (910, 31)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 49494    44086.0  1.071175 -1.089305  ...  0.032596  117.00    0.0
# 193203  130037.0  1.641443 -0.843417  ... -0.022720  237.22    0.0
# 62148    50153.0  1.177948 -0.062102  ...  0.030876   11.50    0.0
# 145179   86695.0 -0.306740  1.070103  ...  0.183904   49.30    0.0
# 152374   97351.0  1.965644 -0.348800  ... -0.040811   14.95    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    455
# 1.0    455
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28      Amount
# Class                                    ...
# 0.0    86635.817582  0.033175 -0.028832  ...  0.002925  0.012102   76.309231
# 1.0    74238.189011 -5.061266  3.797424  ...  0.154087  0.075490  125.899253
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into training and testing data

# %%
X = new_dataset.drop(columns = 'Class', axis = 1)
Y = new_dataset['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (910, 30) (728, 30) (182, 30)

# %% [markdown]
# Training the Model
#
# LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9560439560439561

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Training data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.8956043956043956

# %%
input_data = (0,-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62)

input_data_as_np_array = np.asarray(input_data)

input_data_reshaped = input_data_as_np_array.reshape(1, -1)

prediction = model.predict(input_data_reshaped)

if prediction[0] == 0:
  print('Normal Transaction')
else:
  print('Fraudulent Transaction')
# Out:
# Normal Transaction
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
